# %% [markdown]
# <a href="https://colab.research.google.com/github/mishraabhijit136-jpg/Reminder/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install biopython
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 35.8 MB/s eta 0:00:00
# ...

# %%
from Bio import SeqIO
from Bio.SeqUtils import gc_fraction

# Input FASTA file
fasta_file = "/content/sequence (9).fasta"

# Parse FASTA file
for record in SeqIO.parse(fasta_file,"fasta"):
    seq_id = record.id
    length = len(record.seq)
    gc_content = gc_fraction(record.seq) * 100

    print(f"ID: {seq_id}")
    print(f"Length: {length} bp")
    print(f"GC Content: {gc_content:.2f}%")
    print("-" * 30)
# Out:
# ID: NC_000017.11:c7687490-7668421
# Length: 19070 bp
# GC Content: 49.38%
# ------------------------------
